# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
import requests
from selenium import webdriver

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for **cosmetologist violations** for people with the last name **Nguyen**.

# %%
driver = webdriver.Chrome()
driver.get('https://www.tdlr.texas.gov/cimsfo/fosearch.asp')

# %%
textbox = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[3]/td/select')

# %%
textbox.send_keys('Cosmetologists')

# %%
name_textbox= driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[7]/td/p/input')

# %%
name_textbox.send_keys('Nguyen')

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[18]/td/input[1]').click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
table = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody')


rows = table.find_elements_by_tag_name('tr')

for row in rows:
    print(row.text)
# Out:
# Name and Location Order Basis for Order
# NGUYEN, MIMI PHAM
# City: KATY
# County: HARRIS
# Zip Code: 77449
#
#
# License #: 784210
#
# Complaint # COS20190010072 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# NGUYEN, HA
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76017
#
#
# License #: 764888
#
# Complaint # COS20190016762 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $2,250. Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# NGUYEN, THAO HONG
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78238
#
#
# License #(s): 799926, 1753491
#
# Complaint # COS20200010387 Date: 11/12/2020
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, CINDY
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78414
#
#
# License #(s): 806232, 1260359, 1280071
#
# Complaint # COS20200010502 Date: 10/29/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# NGUYEN, CHAU KHANH LINH
# City: MONTGOMERY
# County: OUT OF STATE
# Zip Code: 36116
#
#
# License #: 1764073
#
# Complaint # COS20190008104 Date: 10/26/2020
#
# The Respondent's Cosmetology Manicurist license is revoked. Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# NGUYEN, TRANG T
# City: SEGUIN
# County: GUADALUPE
# Zip Code: 78155
#
#
# License #: 748483
#
# Complaint # COS20200010511 Date: 10/26/2020
#
# Respondent is assessed an administrative penalty in the amount of $935. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# NGUYEN, DUNG MINH
# City: HOUSTON
# County: HARRIS
# Zip Code: 77066
#
#
# License #: 785878
#
# Complaint # COS20200004202 Date: 10/19/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, YEN NHI THI
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78717
#
#
# License #: 763645
#
# Complaint # COS20190004199 Date: 10/14/2020
#
# Respondent is assessed an administrative penalty in the amount of $675. Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# NGUYEN, JOHNNY DAT
# City: MISSION
# County: HIDALGO
# Zip Code: 78574
#
#
# License #: 797651
#
# Complaint # COS20200000101 Date: 10/14/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.
# NGUYEN, KELLY PHUONG N
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78413
#
#
# License #: 751553
#
# Complaint # COS20200011664 Date: 9/29/2020
#
# Respondent is assessed an administrative penalty in the amount of $625. Respondent failed properly clean and sanitize the metal implements used at the Salon.
# NGUYEN, NGA THU
# City: HOUSTON
# County: HARRIS
# Zip Code: 77038
#
#
# License #: 737176
#
# Complaint # COS20200010961 Date: 9/25/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.
# NGUYEN, IVY
# City: SHERMAN
# County: GRAYSON
# Zip Code: 75092
#
#
# License #: 772886
#
# Complaint # COS20200008858 Date: 8/28/2020
#
# Respondent is assessed an administrative penalty in the amount of $4,450. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# NGUYEN, DIEMTRINH T
# City: CARROLLTON
# County: DALLAS
# Zip Code: 75010
#
#
# License #: 736591
#
# Complaint # COS20200008859 Date: 8/24/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, HUAN CAO
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78229
#
#
# License #: 786237
#
# Complaint # COS20200009732 Date: 8/19/2020
#
# Respondent is assessed an administrative penalty in the amount of $875. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.
# NGUYEN, THOA KIM
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78413
#
#
# License #: 758361
#
# Complaint # COS20200006548 Date: 7/17/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, TONY
# City: MARBLE FALLS
# County: BURNET
# Zip Code: 78654
#
#
# License: Not Licensed
#
# Complaint # COS20200009605 Date: 7/14/2020
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent performed or attempted to perform a practice of cosmetology without a license.
# NGUYEN, HIEN
# City: LONGVIEW
# County: GREGG
# Zip Code: 75605
#
#
# License #: 801727
#
# Complaint # COS20190016479 Date: 4/8/2020
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and disinfect all wax pots.
# NGUYEN, NGOC TRAM
# City: FORT WORTH
# County: TARRANT
# Zip Code: 76137
#
#
# License #: 712767
#
# Complaint # COS20190012148 Date: 3/24/2020
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, TRAN NAM
# City: CANYON
# County: RANDALL
# Zip Code: 79015
#
#
# License #: 733729
#
# Complaint # COS20190010318 Date: 3/16/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to cooperate with the inspector in the performance of an inspection.
# NGUYEN, PHILLIP
# City: EL PASO
# County: EL PASO
# Zip Code: 79912
#
#
# License #: 692372
#
# Complaint # COS20190014688 Date: 3/16/2020
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.
# NGUYEN, THUY T
# City: CARROLLTON
# County: DALLAS
# Zip Code: 75007
#
#
# License #: 794091
#
# Complaint # COS20190004016 Date: 3/3/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.
# NGUYEN, TRACY
# City: FORT WORTH
# County: TARRANT
# Zip Code: 76137
#
#
# License #: 746762
#
# Complaint # COS20190016499 Date: 3/3/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, LE PHUC
# City: SACHSE
# County: COLLIN
# Zip Code: 75048
#
#
# License #: 739879
#
# Complaint # COS20200006146 Date: 2/25/2020
#
# Respondent is assessed an administrative penalty in the amount of $2,250. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, HAI MINH
# City: EL PASO
# County: EL PASO
# Zip Code: 79936
#
#
# License #(s): 726039, 1110890
#
# Complaint # COS20190016549 Date: 2/20/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, TUYET
# City: GRAND PRAIRIE
# County: DALLAS
# Zip Code: 75052
#
#
# License #(s): 774330, 1658860
#
# Complaint # COS20190017217 Date: 2/20/2020
#
# Respondent is assessed an administrative penalty in the amount of $2,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, BA VAN
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76001
#
#
# License #: 676940
#
# Complaint # COS20190016854 Date: 2/10/2020
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# NGUYEN, LAN THANH
# City: DALLAS
# County: DALLAS
# Zip Code: 75216
#
#
# License #: 766697
#
# Complaint # COS20190017175 Date: 2/10/2020
#
# Respondent is assessed an administrative penalty in the amount of $800. Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# NGUYEN, PHUOC BA
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78250
#
#
# License #(s): 788725, 1552617
#
# Complaint # COS20190013017 Date: 1/28/2020
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, LINH THUY KIEU
# City: GARLAND
# County: DALLAS
# Zip Code: 75044
#
#
# License #(s): 795480, 1700076
#
# Complaint # COS20190016161 Date: 1/28/2020
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# NGUYEN, TONY MINH
# City: MARBLE FALLS
# County: BURNET
# Zip Code: 78654
#
#
# License #(s): 791638, 1124706
#
# Complaint # COS20200000652 Date: 1/28/2020
#
# Respondent is assessed an administrative penalty of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, THANH
# City: FRISCO
# County: COLLIN
# Zip Code: 75034
#
#
# License #: 790672
#
# Complaint # COS20190007906 Date: 1/16/2020
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, HIEN THI MINH
# City: HOUSTON
# County: HARRIS
# Zip Code: 77083
#
#
# License #: 795179
#
# Complaint # COS20190003737 Date: 1/10/2020
#
# Respondent is assessed an administrative penalty of $2,625. Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.
# NGUYEN, VAN NGOC THAO
# City: WAXAHACHIE
# County: ELLIS
# Zip Code: 75165
#
#
# License: Not Licensed
#
# Complaint # COS20190006118 Date: 1/10/2020
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.
# NGUYEN, TAM THANH
# City: SAN ANGELO
# County: TOM GREEN
# Zip Code: 76904
#
#
# License #: 1163702
#
# Complaint # COS20200002642 Date: 1/7/2020
#
# Respondent's Cosmetology Manicurist license was revoked by operation of law on 6/13/2019. The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# NGUYEN, ANDY HUU
# City: HURST
# County: TARRANT
# Zip Code: 76053
#
#
# License #(s): 776906, 1189873
#
# Complaint # COS20190009211 Date: 12/18/2019
#
# Respondent is assessed an administrative penalty in the amount of $3,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# NGUYEN, CUONG HULL
# City: GRAND PRAIRIE
# County: TARRANT
# Zip Code: 75052
#
#
# License #(s): 767705, 1094245
#
# Complaint # COS20190010611 Date: 12/12/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, NANCY HOA
# City: GARLAND
# County: DALLAS
# Zip Code: 75044
#
#
# License #(s): 785647, 1121812
#
# Complaint # COS20190010665 Date: 12/12/2019
#
# Respondent is assessed an administrative penalty in the amount of $5,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.
# NGUYEN, THOA THI KIM
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78411
#
#
# License #: 739510
#
# Complaint # COS20190001932 Date: 11/22/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# NGUYEN, TRANG
# City: GARLAND
# County: DALLAS
# Zip Code: 75041
#
#
# License #: 693311
#
# Complaint # COS20190014576 Date: 11/22/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.
# NGUYEN, THONG VAN
# City: EL PASO
# County: EL PASO
# Zip Code: 79912
#
#
# License #: 750663
#
# Complaint # COS20190001897 Date: 11/20/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, TUAN
# City: DALLAS
# County: DALLAS
# Zip Code: 75237
#
#
# License #: 783281
#
# Complaint # COS20190009239 Date: 11/15/2019
#
# Respondent is assessed an administrative penalty in the amount of $2,000. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant.
# NGUYEN, LYNDA
# City: KATY
# County: HARRIS
# Zip Code: 77449
#
#
# License #: 781789
#
# Complaint # COS20190009484 Date: 11/15/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.
# NGUYEN, CATHY H
# City: ROUND ROCK
# County: WILLIAMSON
# Zip Code: 78665
#
# NGUYEN, JOHNNY VAN
# City: ROUND ROCK
# County: WILLIAMSON
# Zip Code: 78665
#
#
# License #: 737930
#
# Complaint # COS20190010323 Date: 11/12/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, PAMELA DAN
# City: SEGUIN
# County: GUADALUPE
# Zip Code: 78155
#
#
# License #: 747589
#
# Complaint # COS20190011923 Date: 11/12/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,010. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.
# NGUYEN, SON QUOC
# City: HILLSBORO
# County: HILL
# Zip Code: 76645
#
#
# License #(s): 772305, 1240974
#
# Complaint # COS20190005539 Date: 11/1/2019
#
# Respondent is assessed an administrative penalty in the amount of $550. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, KIM
# City: DALLAS
# County: DALLAS
# Zip Code: 75240
#
#
# License #: 786602
#
# Complaint # COS20190010176 Date: 11/1/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, THAI VAN
# City: GARLAND
# County: DALLAS
# Zip Code: 75040
#
#
# License #(s): 797287, 1187211
#
# Complaint # COS20190010397 Date: 11/1/2019
#
# Respondent is assessed an administrative penalty in the amount of $3,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, HANH THI
# City: HOUSTON
# County: HARRIS
# Zip Code: 77049
#
#
# License #: 786707
#
# Complaint # COS20190011044 Date: 11/1/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, DIEP THI NGOC
# City: HOUSTON
# County: HARRIS
# Zip Code: 77067
#
#
# License #: 760528
#
# Complaint # COS20190003373 Date: 10/21/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,400. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# NGUYEN, CASEY
# City: CYPRESS
# County: HARRIS
# Zip Code: 77429
#
#
# License #: 790137
#
# Complaint # COS20190010299 Date: 10/21/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, ANTHONY VAN
# City: HALTOM CITY
# County: TARRANT
# Zip Code: 76117
#
#
# License #: 750159
#
# Complaint # COS20190013988 Date: 10/21/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# NGUYEN, CHRISTINA D
# City: PORT ARTHUR
# County: JEFFERSON
# Zip Code: 77642
#
#
# License #: 716740
#
# Complaint # COS20190012652 Date: 10/16/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,625. Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, PHUONG T
# City: HOUSTON
# County: HARRIS
# Zip Code: 77083
#
#
# License #: 748459
#
# Complaint # COS20180015395 Date: 10/3/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# NGUYEN, KENNY
# City: DALLAS
# County: DALLAS
# Zip Code: 75232
#
#
# License #: 75611
#
# Complaint # COS20190010057 Date: 10/3/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, THAO (MINH THAO
# City: LOCKHART
# County: CALDWELL
# Zip Code: 78644
#
#
# License #: 785264
#
# Complaint # COS20190010254 Date: 10/3/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, KENNY
# City: DALLAS
# County: DALLAS
# Zip Code: 75232
#
#
# License #: 756711
#
# Complaint # COS20190000183 Date: 10/2/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,750. Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, BA VAN
# City: MANSFIELD
# County: TARRANT
# Zip Code: 76063
#
#
# License #: 720112
#
# Complaint # COS20190010606 Date: 10/2/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, KHUYEN THI
# City: HALTOM CITY
# County: TARRANT
# Zip Code: 76117
#
#
# License #(s): 771681, 1442799
#
# Complaint # COS20190010961 Date: 10/2/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, SON DANG
# City: FOREST HILL
# County: TARRANT
# Zip Code: 76119
#
#
# License #(s): 720091, 1195752
#
# Complaint # COS20190010635 Date: 10/1/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, TUYEN THANH
# City: AUBREY
# County: DENTON
# Zip Code: 76227
#
#
# License #(s): 792178, 1468619, 1410422
#
# Complaint # COS20190014566 Date: 9/10/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# NGUYEN, STEVEN THAI
# City: CARROLLTON
# County: DALLAS
# Zip Code: 75007
#
#
# License #: 779635
#
# Complaint # COS20190010869 Date: 9/6/2019
#
# Respondent is assessed an administrative penalty in the amount of $6,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, CY VAN
# City: HOUSTON
# County: HARRIS
# Zip Code: 77007
#
#
# License #: 765590
#
# Complaint # COS20190007921 Date: 8/29/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent operated a cosmetology salon without the appropriate license.
# NGUYEN, QUANG DUC
# City: LUBBOCK
# County: LUBBOCK
# Zip Code: 79424
#
#
# License #(s): 749600, 1225146
#
# Complaint # COS20180009800 Date: 8/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $975. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent stored chemicals in a restroom accessible to the public.
# NGUYEN, OANH THI
# City: LIVINGSTON
# County: POLK
# Zip Code: 77351
#
#
# License #: 770502
#
# Complaint # COS20180011968 Date: 8/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,325. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, AN QUY
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78249
#
#
# License #(s): 751433, 1083641
#
# Complaint # COS20180014900 Date: 8/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,150. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# NGUYEN, HAU PHUC
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78414
#
#
# License #: 744770
#
# Complaint # COS20190008675 Date: 8/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent was in possession of bottles containing methyl methacrylate monomer.
# NGUYEN, KIM LIEN THI
# City: AMARILLO
# County: POTTER
# Zip Code: 79107
#
#
# License #: 713587
#
# Complaint # COS20190009912 Date: 8/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, KENNY KHANH
# City: LEANDER
# County: WILLIAMSON
# Zip Code: 78641
#
#
# License #(s): 745308, 1419838
#
# Complaint # COS20190011097 Date: 8/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# NGUYEN, KIM LAN THI
# City: SAN ANGELO
# County: TOM GREEN
# Zip Code: 76901
#
# NGUYEN, THUY TRANG T
# City: SAN ANGELO
# County: TOM GREEN
# Zip Code: 76901
#
#
# License #: 798479
#
# Complaint # COS20190012308 Date: 8/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $900. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used constitutes two violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# NGUYEN, DUONG VAN
# City: CORSICANA
# County: NAVARRO
# Zip Code: 75110
#
#
# License #: 748281
#
# Complaint # COS20180012023 Date: 7/24/2019
#
# Respondent is assessed an administrative penalty in the amount of $950. Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# NGUYEN, HIEU CHAU
# City: EL PASO
# County: EL PASO
# Zip Code: 79938
#
#
# License #: 777856
#
# Complaint # COS20190008542 Date: 7/24/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,875. On two (2) occasions, Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, TRANG KIM
# City: NEW CANEY
# County: MONTGOMERY
# Zip Code: 77357
#
#
# License #: 773798
#
# Complaint # COS20190009430 Date: 7/24/2019
#
# Respondent is assessed an administrative penalty in the amount of $875. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, LINH H
# City: CONVERSE
# County: BEXAR
# Zip Code: 78109
#
#
# License #(s): 78841, 1520821
#
# Complaint # COS20190009953 Date: 7/24/2019
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, PHUONG DUC
# City: PECOS
# County: REEVES
# Zip Code: 79772
#
#
# License #(s): 746023, 1244227, 1549650
#
# Complaint # COS20190010248 Date: 7/24/2019
#
# Respondent is assessed an administrative penalty in the amount of $875. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, NGUYET M
# City: FORT WORTH
# County: TARRANT
# Zip Code: 76116
#
#
# License #(s): 724763, 1327682, 1148025
#
# Complaint # COS20190008693 Date: 7/22/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, VAN DO THI
# City: ALLEN
# County: COLLIN
# Zip Code: 75002
#
#
# License #(s): 749933, 1695846
#
# Complaint # COS20180016583 Date: 7/18/2019
#
# Respondent is assessed an administrative penalty in the amount of $2,000. Respondent performed or attempted to perform a practice of cosmetology with an expired license. Respondent operated a cosmetology salon without the appropriate license.
# NGUYEN, XUAN THI
# City: HOUSTON
# County: HARRIS
# Zip Code: 77066
#
#
# License #: 765777
#
# Complaint # COS20190001467 Date: 7/18/2019
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, MICHAEL TAN
# City: ROCKPORT
# County: ARANSAS
# Zip Code: 78382
#
#
# License #(s): 751319, 1654218
#
# Complaint # COS20190008543 Date: 7/15/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.
# NGUYEN, LANCHI
# City: HOUSTON
# County: HARRIS
# Zip Code: 77015
#
#
# License: Not Licensed
#
# Complaint # COS20190005139 Date: 7/8/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent performed or attempted to perform a practice of cosmetology without a license.
# NGUYEN, DIEM
# City: RICHARDSON
# County: DALLAS
# Zip Code: 75080
#
#
# License #: 688282
#
# Complaint # COS20190010629 Date: 7/8/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, LINH K
# City: HOUSTON
# County: HARRIS
# Zip Code: 77072
#
#
# License #(s): 678261, 871430
#
# Complaint # COS20190010964 Date: 7/8/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, THOANG THI
# City: HOUSTON
# County: HARRIS
# Zip Code: 77075
#
#
# License #: 775443
#
# Complaint # COS20190011791 Date: 7/8/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent employed a person as an operator who did not hold a license.
# NGUYEN, HOAI THU T
# City: EL PASO
# County: EL PASO
# Zip Code: 79925
#
#
# License #: 735244
#
# Complaint # COS20190012199 Date: 7/8/2019
#
# Respondent is assessed an administrative penalty in the amount of $900. Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.
# NGUYEN, JIMMY DUC
# City: GRAPEVINE
# County: TARRANT
# Zip Code: 76051
#
# NGUYEN, MONG
# City: GRAND PRAIRIE
# County: DALLAS
# Zip Code: 75052
#
# NGUYEN, QUI NGOC
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76010
#
#
# License #: 790058
#
# Complaint # COS20190010018 Date: 6/25/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.
# NGUYEN, NINH VAN
# City: GRAND PRAIRIE
# County: TARRANT
# Zip Code: 75052
#
#
# License #: 666588
#
# Complaint # COS20190003941 Date: 6/18/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, THANH HUU
# City: RICHARDSON
# County: DALLAS
# Zip Code: 75081
#
#
# License #(s): 745484, 1259159
#
# Complaint # COS20180004399 Date: 6/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# NGUYEN, UYEN THI TU
# City: LUFKIN
# County: ANGELINA
# Zip Code: 75904
#
#
# License: Not Licensed
#
# Complaint # COS20190001089 Date: 6/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent performed or attempted to perform a practice of cosmetology without a license.
# NGUYEN, BANH THI
# City: TEXARKANA
# County: OUT OF STATE
# Zip Code: 71854
#
#
# License: Not Licensed
#
# Complaint # COS20190007449 Date: 6/4/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent performed barbering without the required license.
# NGUYEN, KHIET THANH
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78413
#
#
# License #: 710894
#
# Complaint # COS20190002450 Date: 5/22/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, SAM DUC
# City: DEL RIO
# County: VAL VERDE
# Zip Code: 78840
#
#
# License #(s): 772341, 1596452
#
# Complaint # COS20190005537 Date: 5/22/2019
#
# Respondent is assessed an administrative penalty in the amount of $900. Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, ANH HUU
# City: PLANO
# County: COLLIN
# Zip Code: 75094
#
# NGUYEN, YEN HONG
# City: PLANO
# County: COLLIN
# Zip Code: 75094
#
#
# License #: 728912
#
# Complaint # COS20180015355 Date: 5/21/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots.
# NGUYEN, DIANE N
# City: SAN ANGELO
# County: TOM GREEN
# Zip Code: 76904
#
#
# License #(s): 681377, 1135046
#
# Complaint # COS20190001468 Date: 5/21/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.
# NGUYEN, MICHAEL
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76014
#
#
# License #(s): 737006, 1155545
#
# Complaint # COS20190003325 Date: 5/21/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, CUONG TRAN
# City: FORT WORTH
# County: TARRANT
# Zip Code: 76137
#
#
# License #: 1594001
#
# Complaint # COS20190006667 Date: 5/1/2019
#
# Respondent's Cosmetology Manicurist license was revoked by operation of law on 04/06/17. The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# NGUYEN, TRAN NAM
# City: CANYON
# County: RANDALL
# Zip Code: 79015
#
#
# License #(s): 690490, 1143200
#
# Complaint # COS20190005115 Date: 4/24/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, TAMMY
# City: ABILENE
# County: TAYLOR
# Zip Code: 79606
#
#
# License #(s): 781568, 1712086, 1234366, 1487516
#
# Complaint # COS20180011336 Date: 4/11/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to cooperate with the inspector in the performance of an inspection.
# NGUYEN, SUONG THI TRUC
# City: SACHSE
# County: COLLIN
# Zip Code: 74048
#
#
# License #: 1695256
#
# Complaint # COS20180002297 Date: 4/9/2019
#
# The Respondent's Cosmetology Manicurist license is revoked. Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# NGUYEN, THE THI
# City: LEVELLAND
# County: HOCKLEY
# Zip Code: 79336
#
#
# License #(s): 728111, 1097604, 1437455
#
# Complaint # COS20180015927 Date: 4/9/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, KIMBERLY
# City: LONGVIEW
# County: GREGG
# Zip Code: 75604
#
#
# License #(s): 785284, 1516790
#
# Complaint # COS20190000507 Date: 4/9/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, DUY KINH
# City: CEDAR PARK
# County: WILLIAMSON
# Zip Code: 78613
#
#
# License #(s): 765758, 1594533
#
# Complaint # COS20190001290 Date: 4/9/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# NGUYEN, LEENA L
# City: EL PASO
# County: EL PASO
# Zip Code: 79924
#
#
# License #: 793631
#
# Complaint # COS20190002573 Date: 4/9/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, MAI TRANG
# City: THE COLONY
# County: DENTON
# Zip Code: 75056
#
#
# License #(s): 792260, 1749538
#
# Complaint # COS20190003107 Date: 4/9/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, HUYEN T
# City: HOUSTON
# County: HARRIS
# Zip Code: 77015
#
#
# License #(s): 774449, 1152042
#
# Complaint # COS20190005137 Date: 4/9/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, TUNG T
# City: TYLER
# County: SMITH
# Zip Code: 75703
#
#
# License #(s): 785431, 1667712
#
# Complaint # COS20190005193 Date: 4/9/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, HIEN XUAN T
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78248
#
#
# License #: 741087
#
# Complaint # COS20190002166 Date: 4/4/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, TUYET
# City: GRAND PRAIRIE
# County: DALLAS
# Zip Code: 75052
#
#
# License #: 774330
#
# Complaint # COS20170022240 Date: 3/27/2019
#
# Respondent is assessed an administrative penalty in the amount of $900. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# NGUYEN, HUYEN THI-MINH
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78727
#
#
# License #(s): 732356, 1440217, 1529693
#
# Complaint # COS20170016527 Date: 3/25/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, HOA VAN
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78753
#
#
# License #: 1216926
#
# Complaint # COS20180003923 Date: 3/22/2019
#
# The Respondent's Cosmetology Manicurist license is revoked. Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.
# NGUYEN, PAUL
# City: MCKINNEY
# County: COLLIN
# Zip Code: 75070
#
#
# License #: 774054
#
# Complaint # COS20180016608 Date: 3/22/2019
#
# Respondent is assessed an administrative penalty in the amount of $3,750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, LOAN HONG ANH
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76002
#
#
# License #: 757086
#
# Complaint # COS20180016630 Date: 3/15/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.
# NGUYEN, MAI THI BACH
# City: WILMER
# County: DALLAS
# Zip Code: 75172
#
#
# License #: 725831
#
# Complaint # COS20190001474 Date: 3/15/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,325. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, TUYET-MAI PHAM
# City: GARLAND
# County: DALLAS
# Zip Code: 75044
#
#
# License #: 786753
#
# Complaint # COS20180008796 Date: 3/4/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, LIEN THI B
# City: LONGVIEW
# County: GREGG
# Zip Code: 75601
#
#
# License #: 794022
#
# Complaint # COS20190005104 Date: 3/4/2019
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent operated a cosmetology salon without the appropriate license; Respondent performed or attempted to perform a practice of cosmetology without a license.
# NGUYEN, MAI T
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78735
#
#
# License #: 750076
#
# Complaint # COS20180013639 Date: 3/1/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, LIEN
# City: AMARILLO
# County: POTTER
# Zip Code: 79109
#
#
# License #: 746980
#
# Complaint # COS20180014831 Date: 2/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to dispose of single use items after each use.
# NGUYEN, NGOC THI
# City: HOUSTON
# County: HARRIS
# Zip Code: 77072
#
#
# License #(s): 737411, 1669514, 1140000, 1240416, 1562212
#
# Complaint # COS20180016402 Date: 2/12/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.
# NGUYEN, VIET LINH
# City: SHERMAN
# County: GRAYSON
# Zip Code: 75092
#
#
# License: Not Licensed
#
# Complaint # COS20190001279 Date: 2/12/2019
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent performed or attempted to perform a practice of cosmetology without a license.
# NGUYEN, COURTNEY
# City: BULLARD
# County: SMITH
# Zip Code: 75757
#
#
# License #: 745292
#
# Complaint # COS20180016048 Date: 2/11/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, TUYEN T
# City: HOUSTON
# County: HARRIS
# Zip Code: 77086
#
#
# License #(s): 790119, 767335, 1680828
#
# Complaint # COS20180016674 Date: 2/11/2019
#
# Respondent is assessed an administrative penalty in the amount of $550. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# NGUYEN, NHON A
# City: KERMIT
# County: WINKLER
# Zip Code: 79745
#
#
# License #: 734240
#
# Complaint # COS20180016648 Date: 1/17/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, SOPHIE T
# City: EL PASO
# County: EL PASO
# Zip Code: 79912
#
#
# License #: 774072
#
# Complaint # COS20180015386 Date: 1/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, NGOC HONG THI
# City: HOUSTON
# County: HARRIS
# Zip Code: 77090
#
#
# License #: 725673
#
# Complaint # COS20180016256 Date: 1/14/2019
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to properly disinfect implements at the end of each day.
# NGUYEN, KHAN THI
# City: BRENHAM
# County: WASHINGTON
# Zip Code: 77833
#
#
# License #(s): 778045, 1290177
#
# Complaint # COS20180003200 Date: 1/10/2019
#
# Respondent is assessed an administrative penalty in the amount of $950. Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.
# NGUYEN, ANNA AI
# City: PLANO
# County: COLLIN
# Zip Code: 75024
#
#
# License #(s): 776928, 1475816
#
# Complaint # COS20180011116 Date: 12/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $550. Respondent failed to clean and disinfect all wax pots.
# NGUYEN, NHU MAI
# City: PLANO
# County: COLLIN
# Zip Code: 75024
#
#
# License #: 745586
#
# Complaint # COS20180016602 Date: 12/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,750. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, DUNG QUANG
# City: DALLAS
# County: DALLAS
# Zip Code: 75206
#
#
# License #(s): 749917, 1165768
#
# Complaint # COS20190001103 Date: 12/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,365. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, MINH THU
# City: EL PASO
# County: EL PASO
# Zip Code: 79934
#
#
# License #: 790174
#
# Complaint # COS20190001603 Date: 12/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent was in possession of bottles containing methyl methacrylate monomer.
# NGUYEN, PHUONG THI
# City: SUGAR LAND
# County: FORT BEND
# Zip Code: 77478
#
#
# License #: 772550
#
# Complaint # COS20180015604 Date: 12/4/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,150. Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day; Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.
# NGUYEN, CHARLIE
# City: DALLAS
# County: DALLAS
# Zip Code: 75219
#
#
# License #: 763659
#
# Complaint # COS20190000020 Date: 12/4/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,125. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent failed to clean and disinfect all wax pots.
# NGUYEN, HANH THI
# City: DALLAS
# County: DALLAS
# Zip Code: 75237
#
#
# License #: 761658
#
# Complaint # COS20180014868 Date: 12/3/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, MINH V
# City: HORIZON CITY
# County: EL PASO
# Zip Code: 79928
#
#
# License #: 745051
#
# Complaint # COS20180010801 Date: 11/14/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# NGUYEN, NHAN THANH
# City: GARLAND
# County: DALLAS
# Zip Code: 75040
#
#
# License #: 1265637
#
# Complaint # COS20180011570 Date: 11/13/2018
#
# Respondent's Cosmetology Manicurist license was revoked by operation of law on 05/07/18. The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# NGUYEN, THUYET
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78251
#
#
# License #: 720045
#
# Complaint # COS20180009490 Date: 11/7/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# NGUYEN, QUANG XUAN
# City: BALCH SPRINGS
# County: DALLAS
# Zip Code: 75180
#
#
# License #(s): 738063, 1231599
#
# Complaint # COS20180014099 Date: 11/7/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,150. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to properly disinfect implements at the end of each day.
# NGUYEN, TRUNG N
# City: AMARILLO
# County: POTTER
# Zip Code: 79106
#
#
# License #(s): 767014, 1196244
#
# Complaint # COS20180007186 Date: 11/6/2018
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to dispose of single use items after each use.
# NGUYEN, MYCAM THI
# City: GARLAND
# County: DALLAS
# Zip Code: 75043
#
#
# License #: 734788
#
# Complaint # COS20180011017 Date: 11/6/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, THUYVI T
# City: PFLUGERVILLE
# County: TRAVIS
# Zip Code: 78660
#
#
# License #: 784702
#
# Complaint # COS20180014315 Date: 11/6/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, OANH PHUONG
# City: KILLEEN
# County: BELL
# Zip Code: 76542
#
#
# License #: 739546
#
# Complaint # COS20180015729 Date: 11/6/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent was in possession of bottles containing methyl methacrylate monomer.
# NGUYEN, QUANG Q
# City: SANTA TERESA
# County: OUT OF STATE
# Zip Code: 88008
#
#
# License #: 771954
#
# Complaint # COS20180012060 Date: 11/2/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, CINDY
# City: CORPUS CHRISTI
# County: NUECES
# Zip Code: 78414
#
#
# License #: 786409
#
# Complaint # COS20180014267 Date: 11/2/2018
#
# Respondent is assessed an administrative penalty in the amount of $2,375. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to ensure that only semi-permanent glue was used during eyelash extension services.
# NGUYEN, KEVIN HOA
# City: ROSEMEAD
# County: OUT OF STATE
# Zip Code: 91770
#
#
# License #: 746655
#
# Complaint # COS20180012949 Date: 10/24/2018
#
# Respondent is assessed an administrative penalty in the amount of $2,000. Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.
# NGUYEN, THUY T
# City: BANDERA
# County: BANDERA
# Zip Code: 78003
#
#
# License #: 720854
#
# Complaint # COS20180014222 Date: 10/24/2018
#
# Respondent is assessed an administrative penalty in the amount of $550. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, THIENTRANG THI
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78735
#
#
# License #(s): 783069, 1655219
#
# Complaint # COS20180010556 Date: 10/23/2018
#
# Respondent is assessed an administrative penalty in the amount of $875. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.
# NGUYEN, MARY ANN
# City: PFLUGERVILLE
# County: TRAVIS
# Zip Code: 78660
#
#
# License: Not Licensed
#
# Complaint # COS20180014330 Date: 10/23/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent performed or attempted to perform a practice of cosmetology without a license.
# NGUYEN, THANH CHUONG
# City: SACHSE
# County: COLLIN
# Zip Code: 75048
#
#
# License #(s): 748957, 1340920
#
# Complaint # COS20180007909 Date: 10/10/2018
#
# Respondent is assessed an administrative penalty in the amount of $2,000. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, PHUONG N
# City: SEALY
# County: AUSTIN
# Zip Code: 77474
#
#
# License #(s): 1199884, 1706073
#
# Complaint # COS20180008524 Date: 10/10/2018
#
# Respondent is assessed an administrative penalty in the amount of $3,000. The Respondent's Cosmetology Esthetician license is revoked. Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# NGUYEN, ANH TRAM
# City: HOUSTON
# County: HARRIS
# Zip Code: 77089
#
#
# License #(s): 759616, 1475221, 1521294
#
# Complaint # COS20180011108 Date: 10/10/2018
#
# Respondent is assessed an administrative penalty in the amount of $375. Respondent failed to dispose of single use items after each use.
# NGUYEN, HIEN
# City: BASTROP
# County: BASTROP
# Zip Code: 78602
#
#
# License: Not Licensed
#
# Complaint # COS20180013126 Date: 9/28/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent performed or attempted to perform a practice of cosmetology without a license.
# NGUYEN, TUAN A
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78723
#
#
# License #: 681274
#
# Complaint # COS20180008708 Date: 9/21/2018
#
# Respondent is assessed an administrative penalty in the amount of $560. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, LEON A
# City: SACHSE
# County: COLLIN
# Zip Code: 75048
#
#
# License #: 1173346
#
# Complaint # COS20180008891 Date: 9/21/2018
#
# The Respondent's Cosmetology Manicurist license is revoked. Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of a crime that was committed within 5 years of their renewal application; Respondent lacks sufficient honesty, trustworthiness and integrity to hold a license.
# NGUYEN, VINH QUANG
# City: EL PASO
# County: EL PASO
# Zip Code: 79901
#
#
# License #: 712441
#
# Complaint # COS20180012418 Date: 9/21/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent was in possession of bottles containing methyl methacrylate monomer.
# NGUYEN, BINH VAN
# City: KILLEEN
# County: BELL
# Zip Code: 76543
#
#
# License #: 756644
#
# Complaint # COS20180015790 Date: 9/21/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent was in possession of bottles containing methyl methacrylate monomer.
# NGUYEN, SHARON
# City: BASTROP
# County: BASTROP
# Zip Code: 78602
#
#
# License #: 750030
#
# Complaint # COS20180013118 Date: 9/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# NGUYEN, BINH THANH
# City: LAREDO
# County: WEBB
# Zip Code: 78045
#
#
# License #: 772744
#
# Complaint # COS20180012368 Date: 9/12/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,500. Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.
# NGUYEN, SAMANTHA TRAN
# City: MCKINNEY
# County: COLLIN
# Zip Code: 75070
#
#
# License #(s): 743492, 1279657, 1562243
#
# Complaint # COS20180006595 Date: 9/4/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,875. Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# NGUYEN, THU LE
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78216
#
#
# License #(s): 11224436, 685119
#
# Complaint # COS20180007798 Date: 8/7/2018
#
# The Respondent's Cosmetology Manicurist license and Cosmetology Manicure Specialty Salon license are revoked. Respondent failed to comply with an order previously issued by the Executive Director.
# NGUYEN, KIM NGAN THI
# City: HOUSTON
# County: HARRIS
# Zip Code: 77084
#
#
# License #: 1434311
#
# Complaint # COS2009004238D Date: 12/9/2009
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent interfered with a Department inspection of the salon.

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    # Instead of stopping on an error, it'll jump down here instead
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement. Most people use `pass`, but it's also nice to print out debug statements so you know when/where it's running into errors.
#
# **Why doesn't the first one have a name?**

# %%
for row in rows[:10]:
    try:
        name = row.find_element_by_class_name('results_text')
        print(name.text)
    except:
        pass
# Out:
# NGUYEN, MIMI PHAM
# NGUYEN, HA
# NGUYEN, THAO HONG
# NGUYEN, CINDY
# NGUYEN, CHAU KHANH LINH
# NGUYEN, TRANG T
# NGUYEN, DUNG MINH
# NGUYEN, YEN NHI THI
# NGUYEN, JOHNNY DAT

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...*

# %%
for row in rows[1:11]:
    cells = row.find_elements_by_tag_name('td')[2]
    print(cells.text)
    print('-------')
# Out:
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# -------
# Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# -------
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# -------
# Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# -------
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# -------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# -------
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# -------
# Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# -------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.
# -------
# Respondent failed properly clean and sanitize the metal implements used at the Salon.
# -------

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
for row in rows[0:10]: 
    try:
        name = row.find_elements_by_class_name('results_text')
        print(name[5].text)
    except:
        pass
# Out:
# COS20190010072
# COS20190016762
# COS20200010387
# COS20200010502
# COS20190008104
# COS20200010511
# COS20200004202
# COS20190004199
# COS20200000101

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
dictionary_list = []
for row in rows[:10]:
    try:
        dictionary = {}
        name = row.find_element_by_class_name('results_text')
        dictionary['name'] = name.text
        description = row.find_elements_by_tag_name('td')[2]
        dictionary['description'] = description.text
        violation_number = row.find_elements_by_class_name('results_text')
        dictionary['violation number'] = violation_number[5].text
        dictionary['license number'] = violation_number[4].text
        dictionary['zip code'] = violation_number[3].text
        dictionary['county'] = violation_number[2].text
        dictionary['city'] = violation_number[1].text
        dictionary_list.append(dictionary)
    except:
        pass
print(dictionary_list)
# Out:
# [{'name': 'NGUYEN, MIMI PHAM', 'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.', 'violation number': 'COS20190010072', 'license number': '784210', 'zip code': '77449', 'county': 'HARRIS', 'city': 'KATY'}, {'name': 'NGUYEN, HA', 'description': 'Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.', 'violation number': 'COS20190016762', 'license number': '764888', 'zip code': '76017', 'county': 'TARRANT', 'city': 'ARLINGTON'}, {'name': 'NGUYEN, THAO HONG', 'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'violation number': 'COS20200010387', 'license number': '799926, 1753491', 'zip code': '78238', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}, {'name': 'NGUYEN, CINDY', 'description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.', 'violation number': 'COS20200010502', 'license number': '806232, 1260359, 1280071', 'zip code': '78414', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}, {'name': 'NGUYEN, CHAU KHANH LINH', 'description': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.', 'violation number': 'COS20190008104', 'license number': '1764073', 'zip code': '36116', 'county': 'OUT OF STATE', 'city': 'MONTGOMERY'}, {'name': 'NGUYEN, TRANG T', 'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.', 'violation number': 'COS20200010511', 'license number': '748483', 'zip code': '78155', 'county': 'GUADALUPE', 'city': 'SEGUIN'}, {'name': 'NGUYEN, DUNG MINH', 'description': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'violation number': 'COS20200004202', 'license number': '785878', 'zip code': '77066', 'county': 'HARRIS', 'city': 'HOUSTON'}, {'name': 'NGUYEN, YEN NHI THI', 'description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.', 'violation number': 'COS20190004199', 'license number': '763645', 'zip code': '78717', 'county': 'TRAVIS', 'city': 'AUSTIN'}, {'name': 'NGUYEN, JOHNNY DAT', 'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.', 'violation number': 'COS20200000101', 'license number': '797651', 'zip code': '78574', 'county': 'HIDALGO', 'city': 'MISSION'}]

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: Use `pd.DataFrame` to create a dataframe, and then save it to a CSV.

# %%
import pandas as pd

# %%
df = pd.DataFrame(dictionary_list)
df.to_csv('nguyen_table', index= False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df = pd.read_csv('nguyen_table')
df
# Out:
#                       name                                        description  \
# 0        NGUYEN, MIMI PHAM  Respondent failed properly clean and sanitize ...
# 1               NGUYEN, HA  Respondent failed to clean and sanitize four (...
# 2        NGUYEN, THAO HONG  Respondent failed to clean, disinfect, and ste...
# 3            NGUYEN, CINDY  Respondent failed to clean and disinfect all w...
# 4  NGUYEN, CHAU KHANH LINH  Respondent engaged in fraud or deceit in obtai...
# 5          NGUYEN, TRANG T  Respondent failed properly clean and sanitize ...
# 6        NGUYEN, DUNG MINH  Respondent failed properly clean and sanitize ...
# 7      NGUYEN, YEN NHI THI  Respondent failed to clean and disinfect all w...
# 8       NGUYEN, JOHNNY DAT  Respondent failed to clean and sanitize whirlp...
#
#   violation number            license number  zip code        county  \
# 0   COS20190010072                    784210     77449        HARRIS
# 1   COS20190016762                    764888     76017       TARRANT
# 2   COS20200010387           799926, 1753491     78238         BEXAR
# 3   COS20200010502  806232, 1260359, 1280071     78414        NUECES
# 4   COS20190008104                   1764073     36116  OUT OF STATE
# 5   COS20200010511                    748483     78155     GUADALUPE
# 6   COS20200004202                    785878     77066        HARRIS
# 7   COS20190004199                    763645     78717        TRAVIS
# 8   COS20200000101                    797651     78574       HIDALGO
#
#              city
# 0            KATY
# 1       ARLINGTON
# 2     SAN ANTONIO
# 3  CORPUS CHRISTI
# 4      MONTGOMERY
# 5          SEGUIN
# 6         HOUSTON
# 7          AUSTIN
# 8         MISSION

# %% [markdown]
# ## Let's do this an easier way
#
# Use Selenium and `pd.read_html` to get the table as a dataframe.

# %%
driver = webdriver.Chrome()
driver.get('https://www.tdlr.texas.gov/cimsfo/fosearch_results.asp')

pd.read_html(table.get_attribute('outerHTML'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-05abbf5418ae> in <module>
# ----> 1 pd.read_html(table.get_attribute('outerHTML'))
#       2
#       3
#       4
#       5
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1084         )
#    1085     validate_header_arg(header)
# -> 1086     return _parse(
#    1087         flavor=flavor,
#    1088         io=io,
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     915             break
#     916     else:
# --> 917         raise retained
#     918
#     919     ret = []
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except ValueError as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/html.py in parse_tables(self)
#     215         list of parsed (header, body, footer) tuples from tables.
#     216         """
# --> 217         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     218         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     219
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     545
#     546         if not tables:
# --> 547             raise ValueError("No tables found")
#     548
#     549         result = []
#
# ValueError: No tables found
